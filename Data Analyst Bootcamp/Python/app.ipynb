# %%
name="Toqeer"
Name="Toqeer G"
print(name)
print(Name)
# Out:
# Toqeer
# Toqeer G

# %%
import numpy as np

# %%
#type inference
var=10
print(type(var))
vars="Toqeer"
print(type(vars))

# indentation
# Out:
# <class 'int'>
# <class 'str'>
