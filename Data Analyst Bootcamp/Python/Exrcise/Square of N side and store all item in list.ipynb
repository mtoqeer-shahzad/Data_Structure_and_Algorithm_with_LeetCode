# %% [markdown]
# Problem Description:
#
# You are given an integer n. Your task is to return a hollow square pattern of size n x n made up of the character '*', represented as a list of strings. The hollow square has '*' on the border, and spaces ' ' in the middle (except for side lengths of 1 and 2).
#
#
#
# Input Parameters:
#
# n (int): The size of the square (number of rows and columns).
#
#
#
# Output:
#
# A list of strings where each string is a row of n characters, representing a hollow square.
#
#
#
# Example:
#
# Input: 3
# Output: ['***', '* *', '***']
#
# Input: 5
# Output: ['*****', '*   *', '*   *', '*   *', '*****']

# %%
def hollow_square(n):
   
    if n == 1:
        return ['*']
    
    square = []
    
    # 1. Top Row
    square.append("*" * n)
    
    # 2. Middle Rows (Should be n - 2)
    for i in range(n - 2):
        square.append("*" + " " * (n - 2) + "*")
    
    # 3. Bottom Row
    square.append("*" * n)
    
    return square

# To see it in action:

# %%
def generate_hollow_square(n):
    """
    Function to return a hollow square pattern of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The size of the square.
    
    Returns:
    list: A list of strings where each string represents a row of the hollow square.
    """
    # Your code here
    
    square=[]
     
    if n==1:
        
        return ['*']
        
    square.append("*" * n)
    
    for i in range(n-2):
        
        square.append("*" + " " * (n-2) + "*")
    
    square.append("*" * n)
    
    
    return square
    

    print(generate_hollow_square(3))

# %%
hollow_square(1)
# Out:
# ['*']

# %%
def generate_square(n):
    """Return Square of number"""
    
    square=[]
    
    for i in range(n):
        square.append("*"*n)
    return square


generate_square(3)
# Out:
# ['***', '***', '***']

# %% [markdown]
# Rectangle Pattern
# Problem Description:
#
# You are given two integers, n and m. Your task is to return a rectangle pattern of '*', where n represents the number of rows (length) and m represents the number of columns (breadth).
#
#
#
# Input:
#
# Two integers n and m, where 1 <= n, m <= 100.
#
#
#
# Output:
#
# A list of strings where each string represents a row of the rectangle pattern.
#
#
#
# Example:
#
# Input: n = 4, m = 5
# Output: ['*****', '*****', '*****', '*****']
#
# Input: n = 3, m = 2
# Output: ['**', '**', '**']
#
#
# Disclaimer: This Udemy coding exercise is still in development, so some advanced complexities might not be fully checked. Please use it primarily for basic code validation.

# %%
def generate_rectangle(n,m):
    
    square=[]
    for i in range(n):
        square.append('*'*m)
    
    return square

# %%
generate_rectangle(4,5)
# Out:
# ['*****', '*****', '*****', '*****']

# %%
def right_angle_triangle(n):
   square=[]
   
   for i in range(1,n+1):
       
       square.append('*'*i)
           
   return square
    
    
right_angle_triangle(3)
# Out:
# ['*', '**', '***']

# %%
right_angle_triangle(4)
# Out:
# ['*', '**', '***', '****']

# %%
def generate_inverted_triangle(n):
    """
    Function to return an inverted right-angled triangle of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The height and base of the triangle.
    
    Returns:
    list: A list of strings where each string represents a row of the triangle.
    """
    # Your code here
    
    
    square=[]
    for i in range(n,0,-1):
        
        square.append("*"*i)
        
    return square

# %%
generate_inverted_triangle(6)
# Out:
# ['******', '*****', '****', '***', '**', '*']

# %%
def generate_pyramid(n):
    
    square=[]
    
    for i in range(n):
        spaces="" * (n-i-1)
        
        star="*" * (2*i+1)
        
        square.append(spaces+star)
    return square

# %%
generate_pyramid(5)
# Out:
# ['*', '***', '*****', '*******', '*********']

# %%
def generate_pyramid(n):
    pyramid = []
    
    for i in range(n):
        # 1. Khali jagah calculate karein
        spaces = "" * (n - i - 1)
        
        # 2. Stars calculate karein (Odd number formula: 2n+1)
        stars = "*" * (2 * i + 1)
        
        # Dono ko mila kar row banayein
        pyramid.append(spaces + stars)
        
    return pyramid

# Check karne ke liye:
# result = 
r2=generate_pyramid(5)
# for row in result:
#     print(row)

# %%
for row in r2:
    print(row)
# Out:
# *
# ***
# *****
# *******
# *********

# %%
def inverted_pyramid(n):
    
    square=[]
    
    
    for i in range(n):
        
        space=''* i
        stars="*" * (2*n-2*i-1)
        square.append(space+stars)
    return square

# %% [markdown]
# # 1. Spaces: 0 se shuru hongi aur i ke saath barhengi

# %%
result=inverted_pyramid(5)
for row in result:
    print(row)
# Out:
# *********
# *******
# *****
# ***
# *

# %%
def generate_inverted_triangle(n):
    return ["*" * (n - i) for i in range(n)]


result_inverted=generate_inverted_triangle(5)

for row in result_inverted:
    print(row)
# Out:
# *****
# ****
# ***
# **
# *
